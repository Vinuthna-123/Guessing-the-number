# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinuthna-123/Guessing-the-number/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXPLORATORY DATA ANALYSIS ON TERRORISM DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING THE DATASET

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
terrorism_df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin-1')
terrorism_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2 scite3 dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN    NaN     PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN    NaN     PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN    NaN     PGIS
# 3              Greece       8  ...      NaN    NaN    NaN    NaN     PGIS
# 4               Japan       4  ...      NaN    NaN    NaN    NaN     PGIS
#
#   INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0     0.0       0.0      0.0     0.0      NaN
# 1     0.0       1.0      1.0     1.0      NaN
# 2    -9.0      -9.0      1.0     1.0      NaN
# 3    -9.0      -9.0      1.0     1.0      NaN
# 4    -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# To VIEW THE SHAPE OF THE DATASET

# %%
print("There are {} rows and {} columns in the dataset".format(terrorism_df.shape[0],terrorism_df.shape[1]))
# Out:
# There are 1895 rows and 12 columns in the dataset

# %%
terrorism_df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %% [markdown]
# CHECKING THE UNIQUENESS OF THE COLUMNS OF DATASET

# %%
No_of_cols=terrorism_df.columns.nunique()
print("There are total %d columns in the data"%No_of_cols)
# Out:
# There are total 12 columns in the data

# %% [markdown]
# RENAME THE COLUMNS WE ARE GOING TO USE FOR ANOTHER ANALYSIS

# %%
terrorism_df=terrorism_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'})
terrorism_df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                       Target_subtype  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                             Gang_name Weapon_type
# 0                              MANO-D     Unknown
# 1  23rd of September Communist League     Unknown
# 2                             Unknown     Unknown
# 3                             Unknown  Explosives
# 4                             Unknown  Incendiary

# %% [markdown]
# SELECTING ONLY THESE COLUMNS WHICH ARE ACTUALLY REQUIRED

# %%
terrorism_df=terrorism_df[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]
terrorism_df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                       Target_subtype  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                             Gang_name Weapon_type
# 0                              MANO-D     Unknown
# 1  23rd of September Communist League     Unknown
# 2                             Unknown     Unknown
# 3                             Unknown  Explosives
# 4                             Unknown  Incendiary

# %% [markdown]
# CHECKING THE UPDATED SHAPE OF THE DATASET

# %%
terrorism_df.shape
# Out:
# (1895, 12)

# %% [markdown]
# CHECKING FOR THE NULL VALUES

# %%
terrorism_df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_type       2
# Target_type       1
# Target_subtype    0
# Gang_name         2
# Weapon_type       2
# dtype: int64

# %% [markdown]
# FILLING THE NAN VALUES

# %%
terrorism_df['Target_subtype'] = terrorism_df['Target_subtype'].fillna('others')
terrorism_df['State']=terrorism_df['State'].fillna('Unknown')
terrorism_df['City']=terrorism_df['City'].fillna('Unknown')
terrorism_df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)
terrorism_df
# Out:
#       Year  Month  Day             Country                       Region  \
# 0     1970      7    2  Dominican Republic  Central America & Caribbean
# 1     1970      0    0              Mexico                North America
# 2     1970      1    0         Philippines               Southeast Asia
# 3     1970      1    0              Greece               Western Europe
# 4     1970      1    0               Japan                    East Asia
# ...    ...    ...  ...                 ...                          ...
# 1890  2011      8    4               India                   South Asia
# 1891  2011      8    4               India                   South Asia
# 1892  2011      8    4               India                   South Asia
# 1893  2011      8    4         Afghanistan                   South Asia
# 1894  2011      8    4                Iraq   Middle East & North Africa
#
#              State                     City                     Attack_type  \
# 0          Unknown            Santo Domingo                   Assassination
# 1          Federal              Mexico city     Hostage Taking (Kidnapping)
# 2           Tarlac                  Unknown                   Assassination
# 3           Attica                   Athens               Bombing/Explosion
# 4          Fukouka                  Fukouka  Facility/Infrastructure Attack
# ...            ...                      ...                             ...
# 1890  Chhattisgarh             Bhopalpatnam                         Unknown
# 1891     Jharkhand  West Singhbhum district  Facility/Infrastructure Attack
# 1892        Odisha                 Jubaguda                   Armed Assault
# 1893        Kunduz                   Kunduz               Bombing/Explosion
# 1894          Al A                  Unknown                             NaN
#
#                       Target_type  \
# 0     Private Citizens & Property
# 1         Government (Diplomatic)
# 2             Journalists & Media
# 3         Government (Diplomatic)
# 4         Government (Diplomatic)
# ...                           ...
# 1890  Private Citizens & Property
# 1891                     Business
# 1892  Private Citizens & Property
# 1893         Government (General)
# 1894                          NaN
#
#                                          Target_subtype  \
# 0                                        Named Civilian
# 1     Diplomatic Personnel (outside of embassy, cons...
# 2                       Radio Journalist/Staff/Facility
# 3                                     Embassy/Consulate
# 4                                     Embassy/Consulate
# ...                                                 ...
# 1890            Laborer (General)/Occupation Identified
# 1891                                       Construction
# 1892                       Unnamed Civilian/Unspecified
# 1893                                       Intelligence
# 1894                                             others
#
#                                            Gang_name Weapon_type
# 0                                             MANO-D     Unknown
# 1                 23rd of September Communist League     Unknown
# 2                                            Unknown     Unknown
# 3                                            Unknown  Explosives
# 4                                            Unknown  Incendiary
# ...                                              ...         ...
# 1890  Communist Party of India - Maoist (CPI-Maoist)     Unknown
# 1891  Communist Party of India - Maoist (CPI-Maoist)  Incendiary
# 1892  Communist Party of India - Maoist (CPI-Maoist)    Firearms
# 1893                                         Taliban  Explosives
# 1894                                             NaN         NaN
#
# [1895 rows x 12 columns]

# %%
terrorism_df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_type       2
# Target_type       1
# Target_subtype    0
# Gang_name         2
# Weapon_type       2
# dtype: int64

# %%
terrorism_df.head(10)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
# 5  1970      1    1       United States                North America
# 6  1970      1    2             Uruguay                South America
# 7  1970      1    2       United States                North America
# 8  1970      1    2       United States                North America
# 9  1970      1    3       United States                North America
#
#         State           City                     Attack_type  \
# 0     Unknown  Santo Domingo                   Assassination
# 1     Federal    Mexico city     Hostage Taking (Kidnapping)
# 2      Tarlac        Unknown                   Assassination
# 3      Attica         Athens               Bombing/Explosion
# 4     Fukouka        Fukouka  Facility/Infrastructure Attack
# 5    Illinois          Cairo                   Armed Assault
# 6  Montevideo     Montevideo                   Assassination
# 7  California        Oakland               Bombing/Explosion
# 8   Wisconsin        Madison  Facility/Infrastructure Attack
# 9   Wisconsin        Madison  Facility/Infrastructure Attack
#
#                    Target_type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                       Target_subtype  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                             Gang_name Weapon_type
# 0                              MANO-D     Unknown
# 1  23rd of September Communist League     Unknown
# 2                             Unknown     Unknown
# 3                             Unknown  Explosives
# 4                             Unknown  Incendiary
# 5                  Black Nationalists    Firearms
# 6                 Tupamaros (Uruguay)    Firearms
# 7                             Unknown  Explosives
# 8                     New Year's Gang  Incendiary
# 9                     New Year's Gang  Incendiary

# %%
terrorism_df.columns.unique()
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %%
terrorism_df.columns.nunique()
# Out:
# 12

# %%
Total_countries=terrorism_df['Country'].nunique()
print("Total %d countries were noted in the data"%Total_countries)
# Out:
# Total 71 countries were noted in the data

# %%
print(terrorism_df['Region'].unique())
# Out:
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia']

# %%
print(terrorism_df['Attack_type'].unique())
# Out:
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)' nan]

# %%
print(terrorism_df['Target_type'].unique())
# Out:
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime'
#  'Cherekskiy District Law Enforcement' nan]

# %%
print(terrorism_df['Weapon_type'].unique())
# Out:
# ['Unknown' 'Explosives' 'Incendiary' 'Firearms' 'Chemical' 'Melee'
#  'Sabotage Equipment' 'Vehicle' nan]

# %%
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            1895 non-null   int64
#  1   Month           1895 non-null   int64
#  2   Day             1895 non-null   int64
#  3   Country         1895 non-null   object
#  4   Region          1895 non-null   object
#  5   State           1895 non-null   object
#  6   City            1895 non-null   object
#  7   Attack_type     1893 non-null   object
#  8   Target_type     1894 non-null   object
#  9   Target_subtype  1895 non-null   object
#  10  Gang_name       1893 non-null   object
#  11  Weapon_type     1893 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 177.8+ KB

# %%
terrorism_df.describe()
# Out:
#               Year        Month          Day
# count  1895.000000  1895.000000  1895.000000
# mean   1985.162005     6.031662    15.263852
# std      19.452285     2.700278     9.107248
# min    1970.000000     0.000000     0.000000
# 25%    1970.000000     4.000000     7.000000
# 50%    1971.000000     6.000000    15.000000
# 75%    2011.000000     7.000000    23.000000
# max    2011.000000    12.000000    31.000000

# %%
terrorism_df['Country'].value_counts().head(10)
# Out:
# United States         740
# Iraq                  176
# Pakistan              148
# United Kingdom        139
# India                  93
# Afghanistan            58
# Turkey                 52
# Uruguay                41
# Philippines            37
# West Germany (FRG)     36
# Name: Country, dtype: int64

# %%
terrorism_df['Region'].value_counts().head(10)
# Out:
# North America                  745
# Middle East & North Africa     312
# South Asia                     300
# Western Europe                 239
# South America                   92
# Sub-Saharan Africa              77
# Southeast Asia                  61
# Eastern Europe                  48
# Central America & Caribbean     13
# East Asia                        6
# Name: Region, dtype: int64

# %%
terrorism_df['State'].value_counts().head(10)
# Out:
# California            220
# New York              141
# Northern Ireland      132
# Baghdad                60
# Montevideo             41
# Sindh                  41
# Khyber Pakhtunkhwa     38
# Illinois               38
# Balochistan            37
# Ankara                 34
# Name: State, dtype: int64

# %%
terrorism_df['Target_subtype'].value_counts().head(10)
# Out:
# School/University/Educational Building                     117
# Police Security Forces/Officers                            113
# Bank/Commerce                                              105
# Government Building/Facility/Office                         92
# Government Personnel (excluding police, military)           92
# Military Personnel (soldiers, troops, officers, forces)     91
# others                                                      86
# Unnamed Civilian/Unspecified                                82
# Retail/Grocery/Bakery                                       81
# Military Barracks/Base/Headquarters/Checkpost               58
# Name: Target_subtype, dtype: int64

# %%
terrorism_df['Weapon_type'].value_counts().head(5)
# Out:
# Explosives    970
# Firearms      445
# Incendiary    302
# Unknown       137
# Melee          29
# Name: Weapon_type, dtype: int64

# %% [markdown]
# VISUALIZING THE DATASET

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 50)
plt.title('Attacks by Weapons Type', fontsize = 25)
sns.countplot(x=terrorism_df.Weapon_type);

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year', fontsize = 25)
sns.countplot(x=terrorism_df.Year);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month', fontsize = 25)
sns.countplot(x=terrorism_df.Month);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Day', fontsize = 25)
sns.countplot(x=terrorism_df.Day);

# %% [markdown]
# ATTACKS BY REGION

# %%
plt.figure(figsize=(28,5));
plt.rcParams.update({'font.size':15});
plt.xticks(rotation = 90)
plt.title('Attacks by Region', fontsize =25)
sns.countplot(x=terrorism_df.Region);

# %% [markdown]
# ATTACKS BASED ON TARGET TYPE

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':15});
plt.xticks(rotation = 90)
plt.title('Based on Target type', fontsize =25)
sns.countplot(x=terrorism_df.Target_type);

# %% [markdown]
# ATTACK BASED ON ATTACK TYPE

# %%
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':15});
plt.xticks(rotation = 90)
plt.title('Based on Attack type', fontsize = 25)
sns.countplot(x=terrorism_df.Attack_type);
